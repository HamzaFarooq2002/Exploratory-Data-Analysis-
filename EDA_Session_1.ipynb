# %% [markdown]
# **EDA Session#1 - Learned about Pandas, Dataframes, Series, did data manipulation and studied best practises.**

# %%
import pandas as pd

# %%
import numpy as np

# %%
days_of_week=pd.Series(["Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday"])

# %%
days_of_week
# Out:
# 0       Monday
# 1      Tuesday
# 2    Wednesday
# 3     Thursday
# 4       Friday
# 5     Saturday
# 6       Sunday
# dtype: object

# %%
population=pd.Series([31.1,111.1,12.2,111.2,1888.9])

# %%
population
# Out:
# 0      31.1
# 1     111.1
# 2      12.2
# 3     111.2
# 4    1888.9
# dtype: float64

# %%
population.name="G5 Population in millions"

# %%
print(population)
# Out:
# 0      31.1
# 1     111.1
# 2      12.2
# 3     111.2
# 4    1888.9
# Name: G5 Population in millions, dtype: float64

# %%
population
# Out:
# 0      31.1
# 1     111.1
# 2      12.2
# 3     111.2
# 4    1888.9
# Name: G5 Population in millions, dtype: float64

# %%
#In order to find data type
population.dtype
# Out:
# dtype('float64')

# %%
days_of_week.dtype
# o = object
# Out:
# dtype('O')

# %%
population.values
# Out:
# array([  31.1,  111.1,   12.2,  111.2, 1888.9])

# %%
population[0]
# Out:
# np.float64(31.1)

# %%
population[2]
# Out:
# np.float64(12.2)

# %%
population.values[0]
# Out:
# np.float64(31.1)

# %%
population.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
population.index=["Pakistan","Bangladesh","China","Iran","USA"]

# %%
print(population)
# Out:
# Pakistan        31.1
# Bangladesh     111.1
# China           12.2
# Iran           111.2
# USA           1888.9
# Name: G5 Population in millions, dtype: float64

# %%
population_g7=

# %%
g7_countries = {
    'Canada': 38.2,
    'France': 65.5,
    'Germany': 83.2,
    'Italy': 59.1,
    'Japan': 125.7,
    'United Kingdom': 67.3,
    'United States': 331.9
}

g7_population = pd.Series(g7_countries, name='G7 Population in millions')
print(g7_population)
# Out:
# Canada             38.2
# France             65.5
# Germany            83.2
# Italy              59.1
# Japan             125.7
# United Kingdom     67.3
# United States     331.9
# Name: G7 Population in millions, dtype: float64

# %%
section={
    "Hamza":23,
    "Salman":20,
    "iKram":30,
    "Yahya":21
}
class_fellows=pd.Series(section, name="School friends")
print (class_fellows)
# Out:
# Hamza     23
# Salman    20
# iKram     30
# Yahya     21
# Name: School friends, dtype: int64

# %%
POPULATION=pd.Series([1,2,3,4,5],
                     index=["a","b","c","d","e"],
                            name="alphabets and numbers")

# %%
print(POPULATION)
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# Name: alphabets and numbers, dtype: int64

# %%
pd.Series(population,index=["USA","Bangladesh"])
# Out:
# USA           1888.9
# Bangladesh     111.1
# Name: G5 Population in millions, dtype: float64

# %%
population.iloc[0]
# Out:
# np.float64(31.1)

# %%
population.iloc[-1]
# Out:
# np.float64(1888.9)

# %%
population[["Bangladesh","Iran"]]
# Out:
# Bangladesh    111.1
# Iran          111.2
# Name: G5 Population in millions, dtype: float64

# %%
population["Pakistan":"USA"]
# Out:
# Pakistan        31.1
# Bangladesh     111.1
# China           12.2
# Iran           111.2
# USA           1888.9
# Name: G5 Population in millions, dtype: float64

# %%
population > 70
# Out:
# Pakistan      False
# Bangladesh     True
# China         False
# Iran           True
# USA            True
# Name: G5 Population in millions, dtype: bool

# %%
population.mean()
# Out:
# np.float64(430.9)

# %%
population.std()
# Out:
# 816.301699740972

# %%
population*1000000
# Out:
# Pakistan      3.110000e+07
# Bangladesh    1.111000e+08
# China         1.220000e+07
# Iran          1.112000e+08
# USA           1.888900e+09
# Name: G5 Population in millions, dtype: float64

# %%
np.log(population)
# Out:
# Pakistan      3.437208
# Bangladesh    4.710431
# China         2.501436
# Iran          4.711330
# USA           7.543750
# Name: G5 Population in millions, dtype: float64

# %%
population[["Pakistan","Iran"]].mean()
# Out:
# np.float64(71.15)

# %%
population["Pakistan":"USA"].mean()
# Out:
# np.float64(430.9)

# %%
population["Pakistan"]=100

# %%
print(population)
# Out:
# Pakistan       100.0
# Bangladesh     111.1
# China           12.2
# Iran           111.2
# USA           1888.9
# Name: G5 Population in millions, dtype: float64

# %%
population.iloc[-1]=400

# %%
print(population)
# Out:
# Pakistan      100.0
# Bangladesh    111.1
# China          12.2
# Iran          111.2
# USA           400.0
# Name: G5 Population in millions, dtype: float64

# %%
population_new=population.copy()

# %%
print(population_new)
# Out:
# Pakistan      100.0
# Bangladesh    111.1
# China          12.2
# Iran          111.2
# USA           400.0
# Name: G5 Population in millions, dtype: float64
